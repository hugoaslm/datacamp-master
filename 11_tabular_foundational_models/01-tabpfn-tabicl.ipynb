# %% [markdown]
# # Introduction to **TabPFN** and **TabICL**
#
# [![Open in Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/x-datascience-datacamp/datacamp-master/blob/main/11_tabular_foundational_models/01-tabpfn-tabicl.ipynb)
#
# Author: [Pedro L. C. Rodrigues](https://plcrodrigues.github.io) and [Thomas Moreau](https://tommoral.github.io)
#
# - **TabPFN** : Hollman et al. "Accurate predictions on small data with a tabular foundation model" (2025) [[link](https://www.nature.com/articles/s41586-024-08328-6)]
# - **TabICL** : Qu et al. "TabICL: A Tabular Foundation Model for In-Context Learning on Large Data" (2025) [[link](https://arxiv.org/abs/2502.05564)]

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from tqdm import tqdm

# %matplotlib inline

# %% [markdown]
# The Python implementation of TabPFN is developed by people from [Prior Labs](https://docs.priorlabs.ai/overview) and follows the same API from `scikit-learn`.
#
# Note, however, that to use the last version of the TabPFN's foundational model, you will need to authenticate at HuggingFace, which can be a bit messy. Because of this, we will be focusing on TabPFN-V2, which should be more than enough.
#
# ⚡ GPU Recommended: For optimal performance, use a GPU (even older ones with ~8GB VRAM work well; 16GB needed for some large datasets). On CPU, only small datasets (≲1000 samples) are feasible. Note that **this notebook can be run on Codalab with the top button**.
#
# First of all, you will need to install the package by as below

# %%
# !pip install -U tabpfn
# Out:
# Collecting tabpfn
#   Downloading tabpfn-6.1.0-py3-none-any.whl.metadata (36 kB)
# Requirement already satisfied: torch<3,>=2.1 in /usr/local/lib/python3.12/dist-packages (from tabpfn) (2.9.0+cu126)
# Requirement already satisfied: numpy<3,>=1.21.6 in /usr/local/lib/python3.12/dist-packages (from tabpfn) (2.0.2)
# Requirement already satisfied: scikit-learn<1.8,>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from tabpfn) (1.6.1)
# Requirement already satisfied: typing_extensions>=4.12.0 in /usr/local/lib/python3.12/dist-packages (from tabpfn) (4.15.0)
# Requirement already satisfied: scipy<2,>=1.11.1 in /usr/local/lib/python3.12/dist-packages (from tabpfn) (1.16.3)
# Requirement already satisfied: pandas<3,>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from tabpfn) (2.2.2)
# Requirement already satisfied: einops<0.9,>=0.2.0 in /usr/local/lib/python3.12/dist-packages (from tabpfn) (0.8.1)
# Requirement already satisfied: huggingface-hub<2,>=0.19.0 in /usr/local/lib/python3.12/dist-packages (from tabpfn) (0.36.0)
# Requirement already satisfied: pydantic>=2.8.0 in /usr/local/lib/python3.12/dist-packages (from tabpfn) (2.12.3)
# Requirement already satisfied: pydantic-settings>=2.10.1 in /usr/local/lib/python3.12/dist-packages (from tabpfn) (2.12.0)
# Collecting eval-type-backport>=0.2.2 (from tabpfn)
#   Downloading eval_type_backport-0.3.1-py3-none-any.whl.metadata (2.4 kB)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from tabpfn) (1.5.2)
# Collecting tabpfn-common-utils>=0.2.8 (from tabpfn-common-utils[telemetry-interactive]>=0.2.8->tabpfn)
#   Downloading tabpfn_common_utils-0.2.12-py3-none-any.whl.metadata (5.4 kB)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2,>=0.19.0->tabpfn) (3.20.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2,>=0.19.0->tabpfn) (2025.3.0)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2,>=0.19.0->tabpfn) (25.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2,>=0.19.0->tabpfn) (6.0.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2,>=0.19.0->tabpfn) (2.32.4)
# Requirement already satisfied: tqdm>=4.42.1 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2,>=0.19.0->tabpfn) (4.67.1)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2,>=0.19.0->tabpfn) (1.2.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas<3,>=1.4.0->tabpfn) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas<3,>=1.4.0->tabpfn) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas<3,>=1.4.0->tabpfn) (2025.2)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic>=2.8.0->tabpfn) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.4 in /usr/local/lib/python3.12/dist-packages (from pydantic>=2.8.0->tabpfn) (2.41.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in /usr/local/lib/python3.12/dist-packages (from pydantic>=2.8.0->tabpfn) (0.4.2)
# Requirement already satisfied: python-dotenv>=0.21.0 in /usr/local/lib/python3.12/dist-packages (from pydantic-settings>=2.10.1->tabpfn) (1.2.1)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn<1.8,>=1.2.0->tabpfn) (3.6.0)
# Requirement already satisfied: platformdirs>=4 in /usr/local/lib/python3.12/dist-packages (from tabpfn-common-utils>=0.2.8->tabpfn-common-utils[telemetry-interactive]>=0.2.8->tabpfn) (4.5.1)
# Collecting posthog~=6.7 (from tabpfn-common-utils>=0.2.8->tabpfn-common-utils[telemetry-interactive]>=0.2.8->tabpfn)
#   Downloading posthog-6.9.3-py3-none-any.whl.metadata (6.0 kB)
# Collecting requests (from huggingface-hub<2,>=0.19.0->tabpfn)
#   Downloading requests-2.32.5-py3-none-any.whl.metadata (4.9 kB)
# Requirement already satisfied: ruff>=0.11.6 in /usr/local/lib/python3.12/dist-packages (from tabpfn-common-utils>=0.2.8->tabpfn-common-utils[telemetry-interactive]>=0.2.8->tabpfn) (0.14.8)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.1->tabpfn) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.1->tabpfn) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.1->tabpfn) (3.6.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.1->tabpfn) (3.1.6)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.1->tabpfn) (12.6.77)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.1->tabpfn) (12.6.77)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.6.80 in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.1->tabpfn) (12.6.80)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.1->tabpfn) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.6.4.1 in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.1->tabpfn) (12.6.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.0.4 in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.1->tabpfn) (11.3.0.4)
# Requirement already satisfied: nvidia-curand-cu12==10.3.7.77 in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.1->tabpfn) (10.3.7.77)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.1.2 in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.1->tabpfn) (11.7.1.2)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.4.2 in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.1->tabpfn) (12.5.4.2)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.1->tabpfn) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.5 in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.1->tabpfn) (2.27.5)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.3.20 in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.1->tabpfn) (3.3.20)
# Requirement already satisfied: nvidia-nvtx-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.1->tabpfn) (12.6.77)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.6.85 in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.1->tabpfn) (12.6.85)
# Requirement already satisfied: nvidia-cufile-cu12==1.11.1.6 in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.1->tabpfn) (1.11.1.6)
# Requirement already satisfied: triton==3.5.0 in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.1->tabpfn) (3.5.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from posthog~=6.7->tabpfn-common-utils>=0.2.8->tabpfn-common-utils[telemetry-interactive]>=0.2.8->tabpfn) (1.17.0)
# Collecting backoff>=1.10.0 (from posthog~=6.7->tabpfn-common-utils>=0.2.8->tabpfn-common-utils[telemetry-interactive]>=0.2.8->tabpfn)
#   Downloading backoff-2.2.1-py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: distro>=1.5.0 in /usr/local/lib/python3.12/dist-packages (from posthog~=6.7->tabpfn-common-utils>=0.2.8->tabpfn-common-utils[telemetry-interactive]>=0.2.8->tabpfn) (1.9.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->huggingface-hub<2,>=0.19.0->tabpfn) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->huggingface-hub<2,>=0.19.0->tabpfn) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->huggingface-hub<2,>=0.19.0->tabpfn) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->huggingface-hub<2,>=0.19.0->tabpfn) (2025.11.12)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch<3,>=2.1->tabpfn) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch<3,>=2.1->tabpfn) (3.0.3)
# Downloading tabpfn-6.1.0-py3-none-any.whl (553 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 553.2/553.2 kB 12.5 MB/s eta 0:00:00
# Downloading eval_type_backport-0.3.1-py3-none-any.whl (6.1 kB)
# Downloading tabpfn_common_utils-0.2.12-py3-none-any.whl (34 kB)
# Downloading posthog-6.9.3-py3-none-any.whl (144 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 144.7/144.7 kB 6.4 MB/s eta 0:00:00
# Downloading requests-2.32.5-py3-none-any.whl (64 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 64.7/64.7 kB 2.5 MB/s eta 0:00:00
# Downloading backoff-2.2.1-py3-none-any.whl (15 kB)
# Installing collected packages: requests, eval-type-backport, backoff, posthog, tabpfn-common-utils, tabpfn
#   Attempting uninstall: requests
#     Found existing installation: requests 2.32.4
#     Uninstalling requests-2.32.4:
#       Successfully uninstalled requests-2.32.4
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-colab 1.0.0 requires requests==2.32.4, but you have requests 2.32.5 which is incompatible.
# Successfully installed backoff-2.2.1 eval-type-backport-0.3.1 posthog-6.9.3 requests-2.32.5 tabpfn-6.1.0 tabpfn-common-utils-0.2.12

# %% [markdown]
# # Regression with TabPFN
#
# We investigate how TabPFN can be used for regression and compare his performance versus other classic regressors.

# %%
from sklearn.utils import shuffle
from sklearn.model_selection import KFold, cross_val_score
from sklearn.datasets import fetch_california_housing, load_diabetes

from tabpfn import TabPFNRegressor
from tabpfn.constants import ModelVersion

import pandas as pd, requests

# Loading the Boston dataset
cols = ["CRIM","ZN","INDUS","CHAS","NOX","RM","AGE","DIS","RAD","TAX","PTRATIO","B","LSTAT","MEDV"]
df_boston = pd.read_csv("https://archive.ics.uci.edu/ml/machine-learning-databases/housing/housing.data",
                        sep='\\s+', header=None, names=cols)

print(df_boston.shape)
df_boston.head()
# Out:
# (506, 14)
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296.0
# 1  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242.0
# 2  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242.0
# 3  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222.0
# 4  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222.0
#
#    PTRATIO       B  LSTAT  MEDV
# 0     15.3  396.90   4.98  24.0
# 1     17.8  396.90   9.14  21.6
# 2     17.8  392.83   4.03  34.7
# 3     18.7  394.63   2.94  33.4
# 4     18.7  396.90   5.33  36.2

# %%
from huggingface_hub import login
login()
# Out:
# VBox(children=(HTML(value='<center> <img\nsrc=https://huggingface.co/front/assets/huggingface_logo-noborder.sv…

# %%
# Convert to pure numpy arrays
X, y = df_boston.drop(columns=["MEDV"]).values, df_boston["MEDV"].values

# Choose cross-validation strategy
cv = KFold(shuffle=True, n_splits=5)

# Instantiate TabPFN for regression
regressor_tabpfn = TabPFNRegressor()
#regressor_tabpfn = TabPFNRegressor.create_default_for_version(ModelVersion.V2)
regressor_tabpfn.n_estimators = 1

scores = []
for idx_train, idx_test in tqdm(cv.split(X, y)):
    X_train, y_train = X[idx_train], y[idx_train]
    X_test, y_test = X[idx_test], y[idx_test]
    regressor_tabpfn.fit(X_train, y_train)
    scores.append(regressor_tabpfn.score(X_test, y_test))
print(np.mean(scores))
# Out:
# 0it [00:00, ?it/s]
# tabpfn-v2.5-regressor-v2.5_default.ckpt:   0%|          | 0.00/40.8M [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/35.0 [00:00<?, ?B/s]
# 5it [00:03,  1.40it/s]
# 0.9074041393406524

# %% [markdown]
# <div class="alert alert-success">
#     <b>EXERCISE</b>:
#      <ul>
#          <li>What is happening in the <span><code>fit</code></span> method?</li>
#      </ul>
# </div>

# %% [markdown]
# Let's see now how a `RandomForestRegressor` and the `HistGradientRegressor` behave

# %%
from sklearn.ensemble import RandomForestRegressor, HistGradientBoostingRegressor
regressor_rf = RandomForestRegressor()
regressor_hgbr = HistGradientBoostingRegressor()
est_dict = {'rf':regressor_rf, 'hgbr':regressor_hgbr}
for key, value in est_dict.items():
    scores = cross_val_score(value, X, y, cv=cv)
    print(key, np.mean(scores))
# Out:
# rf 0.8542893363591315
# hgbr 0.8589642198354154

# %% [markdown]
# We see that TabPFN beats both baseslines by quite a margin. However, it took much more time...

# %% [markdown]
# Let's consider now a different dataset.

# %%
from sklearn.datasets import fetch_california_housing
df_california, targets = fetch_california_housing(return_X_y=True, as_frame=True)
print(df_california.shape)
df_california.head()
# Out:
# (20640, 8)
#    MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0  8.3252      41.0  6.984127   1.023810       322.0  2.555556     37.88
# 1  8.3014      21.0  6.238137   0.971880      2401.0  2.109842     37.86
# 2  7.2574      52.0  8.288136   1.073446       496.0  2.802260     37.85
# 3  5.6431      52.0  5.817352   1.073059       558.0  2.547945     37.85
# 4  3.8462      52.0  6.281853   1.081081       565.0  2.181467     37.85
#
#    Longitude
# 0    -122.23
# 1    -122.22
# 2    -122.24
# 3    -122.25
# 4    -122.25

# %% [markdown]
# The dataset is bigger than the previous one, so let's see how TabPFN behaves.

# %%
from sklearn.model_selection import train_test_split # let's avoid cross-val for time sake
X, y = df_california.values, targets.values
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42)
regressor_tabpfn.fit(X_train, y_train)
print(regressor_tabpfn.score(X_test, y_test))
# Out:
# 0.874954307823786

# %% [markdown]
# <div class="alert alert-success">
#     <b>EXERCISE</b>:
#      <ul>
#          <li>Why do you think we exploded in memory?</li>
#      </ul>
# </div>

# %% [markdown]
# One possible trick is to subsample the dataset and use an ensemble of TabPFN regressors as below.

# %%
regressor_tabpfn.ignore_pretraining_limits = True
regressor_tabpfn.n_estimators = 1
regressor_tabpfn.inference_config = {"SUBSAMPLE_SAMPLES": 500}
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42)
regressor_tabpfn.fit(X_train, y_train)
print(regressor_tabpfn.score(X_test, y_test))

# %% [markdown]
# Or even better, use a GPU :-)
#
# [![Open in Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/x-datascience-datacamp/datacamp-master/blob/main/11_tabular_foundational_models/01-tabpfn-tabicl.ipynb)

# %%
regressor_rf = RandomForestRegressor()
regressor_hgbr = HistGradientBoostingRegressor()
est_dict = {'rf':regressor_rf, 'hgbr':regressor_hgbr}
for key, est in est_dict.items():
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42)
    est.fit(X_train, y_train)
    score = est.score(X_test, y_test)
    print(key, score)
# Out:
# rf 0.8050664968727209
# hgbr 0.8374422154968123

# %% [markdown]
# In the slides, we saw that **TabICL** can, in principle, scale to any number of samples, due to the way that rows and columns are embedded in its architecture. So should we try to use it?

# %%
# !pip install -U tabicl # watch out for the python version!
# Out:
# Collecting tabicl
#   Downloading tabicl-0.1.4-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: einops>=0.7 in /usr/local/lib/python3.12/dist-packages (from tabicl) (0.8.1)
# Requirement already satisfied: huggingface-hub in /usr/local/lib/python3.12/dist-packages (from tabicl) (0.36.0)
# Requirement already satisfied: joblib in /usr/local/lib/python3.12/dist-packages (from tabicl) (1.5.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from tabicl) (2.0.2)
# Requirement already satisfied: psutil in /usr/local/lib/python3.12/dist-packages (from tabicl) (5.9.5)
# Requirement already satisfied: scikit-learn>=1.3.0 in /usr/local/lib/python3.12/dist-packages (from tabicl) (1.6.1)
# Requirement already satisfied: scipy in /usr/local/lib/python3.12/dist-packages (from tabicl) (1.16.3)
# Requirement already satisfied: torch<3,>=2.2 in /usr/local/lib/python3.12/dist-packages (from tabicl) (2.9.0+cu126)
# Requirement already satisfied: tqdm>=4.64.0 in /usr/local/lib/python3.12/dist-packages (from tabicl) (4.67.1)
# Requirement already satisfied: transformers in /usr/local/lib/python3.12/dist-packages (from tabicl) (4.57.3)
# Requirement already satisfied: wandb in /usr/local/lib/python3.12/dist-packages (from tabicl) (0.23.1)
# Requirement already satisfied: xgboost in /usr/local/lib/python3.12/dist-packages (from tabicl) (3.1.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn>=1.3.0->tabicl) (3.6.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.2->tabicl) (3.20.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.2->tabicl) (4.15.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.2->tabicl) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.2->tabicl) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.2->tabicl) (3.6.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.2->tabicl) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.2->tabicl) (2025.3.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.2->tabicl) (12.6.77)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.2->tabicl) (12.6.77)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.6.80 in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.2->tabicl) (12.6.80)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.2->tabicl) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.6.4.1 in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.2->tabicl) (12.6.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.0.4 in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.2->tabicl) (11.3.0.4)
# Requirement already satisfied: nvidia-curand-cu12==10.3.7.77 in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.2->tabicl) (10.3.7.77)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.1.2 in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.2->tabicl) (11.7.1.2)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.4.2 in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.2->tabicl) (12.5.4.2)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.2->tabicl) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.5 in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.2->tabicl) (2.27.5)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.3.20 in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.2->tabicl) (3.3.20)
# Requirement already satisfied: nvidia-nvtx-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.2->tabicl) (12.6.77)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.6.85 in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.2->tabicl) (12.6.85)
# Requirement already satisfied: nvidia-cufile-cu12==1.11.1.6 in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.2->tabicl) (1.11.1.6)
# Requirement already satisfied: triton==3.5.0 in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.2->tabicl) (3.5.0)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub->tabicl) (25.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub->tabicl) (6.0.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from huggingface-hub->tabicl) (2.32.5)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub->tabicl) (1.2.0)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.12/dist-packages (from transformers->tabicl) (2025.11.3)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in /usr/local/lib/python3.12/dist-packages (from transformers->tabicl) (0.22.1)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.12/dist-packages (from transformers->tabicl) (0.7.0)
# Requirement already satisfied: click>=8.0.1 in /usr/local/lib/python3.12/dist-packages (from wandb->tabicl) (8.3.1)
# Requirement already satisfied: gitpython!=3.1.29,>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from wandb->tabicl) (3.1.45)
# Requirement already satisfied: platformdirs in /usr/local/lib/python3.12/dist-packages (from wandb->tabicl) (4.5.1)
# Requirement already satisfied: protobuf!=4.21.0,!=5.28.0,<7,>=3.19.0 in /usr/local/lib/python3.12/dist-packages (from wandb->tabicl) (5.29.5)
# Requirement already satisfied: pydantic<3 in /usr/local/lib/python3.12/dist-packages (from wandb->tabicl) (2.12.3)
# Requirement already satisfied: sentry-sdk>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from wandb->tabicl) (2.47.0)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /usr/local/lib/python3.12/dist-packages (from gitpython!=3.1.29,>=1.0.0->wandb->tabicl) (4.0.12)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic<3->wandb->tabicl) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.4 in /usr/local/lib/python3.12/dist-packages (from pydantic<3->wandb->tabicl) (2.41.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in /usr/local/lib/python3.12/dist-packages (from pydantic<3->wandb->tabicl) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->huggingface-hub->tabicl) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->huggingface-hub->tabicl) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->huggingface-hub->tabicl) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->huggingface-hub->tabicl) (2025.11.12)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch<3,>=2.2->tabicl) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch<3,>=2.2->tabicl) (3.0.3)
# Requirement already satisfied: smmap<6,>=3.0.1 in /usr/local/lib/python3.12/dist-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.29,>=1.0.0->wandb->tabicl) (5.0.2)
# Downloading tabicl-0.1.4-py3-none-any.whl (107 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 107.8/107.8 kB 5.0 MB/s eta 0:00:00
# Installing collected packages: tabicl
# Successfully installed tabicl-0.1.4

# %% [markdown]
# Checking the **TabICL** [documentation](https://github.com/soda-inria/tabicl) we notice that it currently does not work for regression... :'(
#
# At least for now... ;)

# %% [markdown]
# <div class="alert alert-success">
#     <b>EXERCISE</b>:
#      <ul>
#          <li>Why can TabPFN do regression out-of-the-box whereas TabICL not?</li>
#      </ul>
# </div>

# %% [markdown]
# # Classification with TabPFN and TabICL
#
# Let's switch to a classifcation problem first with a small then with a big dataset.

# %%
from sklearn.datasets import fetch_openml
df, target = fetch_openml("titanic", version=1, as_frame=True, return_X_y=True)
X, y = df.values, target.values
df.head()
# Out:
#    pclass                                             name     sex      age  \
# 0       1                    Allen, Miss. Elisabeth Walton  female  29.0000
# 1       1                   Allison, Master. Hudson Trevor    male   0.9167
# 2       1                     Allison, Miss. Helen Loraine  female   2.0000
# 3       1             Allison, Mr. Hudson Joshua Creighton    male  30.0000
# 4       1  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female  25.0000
#
#    sibsp  parch  ticket      fare    cabin embarked boat   body  \
# 0      0      0   24160  211.3375       B5        S    2    NaN
# 1      1      2  113781  151.5500  C22 C26        S   11    NaN
# 2      1      2  113781  151.5500  C22 C26        S  NaN    NaN
# 3      1      2  113781  151.5500  C22 C26        S  NaN  135.0
# 4      1      2  113781  151.5500  C22 C26        S  NaN    NaN
#
#                          home.dest
# 0                     St Louis, MO
# 1  Montreal, PQ / Chesterville, ON
# 2  Montreal, PQ / Chesterville, ON
# 3  Montreal, PQ / Chesterville, ON
# 4  Montreal, PQ / Chesterville, ON

# %% [markdown]
# We saw in previous classes that we can not simply plug the Titanic dataset into standard scikit-learn estimators. First, it is necessary to pre-process the data, encode categorical features, etc. But what happens in TabPFN ?

# %%
from sklearn.model_selection import StratifiedKFold
cv = StratifiedKFold(shuffle=True, n_splits=5)

# Instantiate TabPFN for classification
from tabpfn import TabPFNClassifier
clf_tabpfn = TabPFNClassifier.create_default_for_version(ModelVersion.V2)
clf_tabpfn.n_estimators = 1

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42)
clf_tabpfn.fit(X_train, y_train)
print(clf_tabpfn.score(X_test, y_test))
# Out:
# tabpfn-v2-classifier-finetuned-zk73skhh.(…):   0%|          | 0.00/29.0M [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/37.0 [00:00<?, ?B/s]
# 0.9699074074074074

# %% [markdown]
# What about TabICL ?

# %%
from tabicl import TabICLClassifier
clf_icl = TabICLClassifier(n_estimators=1)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42)
clf_icl.fit(X_train, y_train)
print(clf_icl.score(X_test, y_test))
# Out:
# INFO: You are downloading 'tabicl-classifier-v1.1-0506.ckpt', the latest best-performing version of TabICL.
# To reproduce results from the original paper, please use 'tabicl-classifier-v1-0208.ckpt'.
#
# Checkpoint 'tabicl-classifier-v1.1-0506.ckpt' not cached.
#  Downloading from Hugging Face Hub (jingang/TabICL-clf).
# tabicl-classifier-v1.1-0506.ckpt:   0%|          | 0.00/108M [00:00<?, ?B/s]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipython-input-818640819.py in <cell line: 0>()
#       2 clf_icl = TabICLClassifier(n_estimators=1)
#       3 X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42)
# ----> 4 clf_icl.fit(X_train, y_train)
#       5 print(clf_icl.score(X_test, y_test))
#
# /usr/local/lib/python3.12/dist-packages/tabicl/sklearn/classifier.py in fit(self, X, y)
#     426             random_state=self.random_state,
#     427         )
# --> 428         self.ensemble_generator_.fit(X, y)
#     429
#     430         return self
#
# /usr/local/lib/python3.12/dist-packages/tabicl/sklearn/preprocessing.py in fit(self, X, y)
#     915             raise ValueError(f"{self.__class__.__name__} requires y to be passed, but the target y is None")
#     916
# --> 917         validate_data(self, X, y)
#     918
#     919         if self.norm_methods is None:
#
# /usr/local/lib/python3.12/dist-packages/tabicl/sklearn/sklearn_utils.py in validate_data(_estimator, X, y, reset, validate_separately, skip_check_array, **check_params)
#     392             y = check_array(y, input_name="y", **check_y_params)
#     393         else:
# --> 394             X, y = check_X_y(X, y, **check_params)
#     395         out = X, y
#     396
#
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py in check_X_y(X, y, accept_sparse, accept_large_sparse, dtype, order, copy, force_writeable, force_all_finite, ensure_all_finite, ensure_2d, allow_nd, multi_output, ensure_min_samples, ensure_min_features, y_numeric, estimator)
#    1368     ensure_all_finite = _deprecate_force_all_finite(force_all_finite, ensure_all_finite)
#    1369
# -> 1370     X = check_array(
#    1371         X,
#    1372         accept_sparse=accept_sparse,
#
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_writeable, force_all_finite, ensure_all_finite, ensure_non_negative, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator, input_name)
#    1053                     array = xp.astype(array, dtype, copy=False)
#    1054                 else:
# -> 1055                     array = _asarray_with_order(array, order=order, dtype=dtype, xp=xp)
#    1056             except ComplexWarning as complex_warning:
#    1057                 raise ValueError(
#
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/_array_api.py in _asarray_with_order(array, dtype, order, copy, xp, device)
#     837             array = numpy.array(array, order=order, dtype=dtype)
#     838         else:
# --> 839             array = numpy.asarray(array, order=order, dtype=dtype)
#     840
#     841         # At this point array is a NumPy ndarray. We convert it to an array
#
# ValueError: could not convert string to float: 'Collett, Mr. Sidney C Stuart'

# %% [markdown]
# The documention can help us : https://github.com/soda-inria/tabicl?tab=readme-ov-file#basic-integration

# %%
# !pip install -U skrub
# Out:
# Collecting skrub
#   Downloading skrub-0.7.0-py3-none-any.whl.metadata (4.4 kB)
# Requirement already satisfied: numpy>=1.23.5 in /usr/local/lib/python3.12/dist-packages (from skrub) (2.0.2)
# Requirement already satisfied: pandas>=1.5.3 in /usr/local/lib/python3.12/dist-packages (from skrub) (2.2.2)
# Requirement already satisfied: scikit-learn>=1.4.2 in /usr/local/lib/python3.12/dist-packages (from skrub) (1.6.1)
# Requirement already satisfied: scipy>=1.9.3 in /usr/local/lib/python3.12/dist-packages (from skrub) (1.16.3)
# Requirement already satisfied: jinja2>=3.1.2 in /usr/local/lib/python3.12/dist-packages (from skrub) (3.1.6)
# Requirement already satisfied: matplotlib>=3.4.3 in /usr/local/lib/python3.12/dist-packages (from skrub) (3.10.0)
# Requirement already satisfied: requests>=2.27.1 in /usr/local/lib/python3.12/dist-packages (from skrub) (2.32.5)
# Requirement already satisfied: pydot in /usr/local/lib/python3.12/dist-packages (from skrub) (4.0.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2>=3.1.2->skrub) (3.0.3)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.4.3->skrub) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.4.3->skrub) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.4.3->skrub) (4.61.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.4.3->skrub) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.4.3->skrub) (25.0)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.4.3->skrub) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.4.3->skrub) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.4.3->skrub) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas>=1.5.3->skrub) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas>=1.5.3->skrub) (2025.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.27.1->skrub) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests>=2.27.1->skrub) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests>=2.27.1->skrub) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests>=2.27.1->skrub) (2025.11.12)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn>=1.4.2->skrub) (1.5.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn>=1.4.2->skrub) (3.6.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib>=3.4.3->skrub) (1.17.0)
# Downloading skrub-0.7.0-py3-none-any.whl (498 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 498.3/498.3 kB 14.0 MB/s eta 0:00:00
# Installing collected packages: skrub
# Successfully installed skrub-0.7.0

# %%
from skrub import TableVectorizer
from tabicl import TabICLClassifier
from sklearn.pipeline import make_pipeline

pipeline = make_pipeline(
    TableVectorizer(),  # automatically handles various data types
    TabICLClassifier(n_estimators=8)  # beware of the default parameters!
)

X_train, X_test, y_train, y_test = train_test_split(df, target, test_size=0.33, random_state=42) # note that we pass the dataframe!
pipeline.fit(X_train, y_train)
print(pipeline.score(X_test, y_test))
# Out:
# 1.0

# %% [markdown]
# <div class="alert alert-success">
#     <b>EXERCISE</b>:
#      <ul>
#          <li>Why can TabPFN preprocess categorical features directly and TabICL needs a pipeline?</li>
#      </ul>
# </div>

# %%
from skrub import tabular_pipeline
est = tabular_pipeline('classifier')
X_train, X_test, y_train, y_test = train_test_split(df, target, test_size=0.33, random_state=42) # note that we pass the dataframe!
est.fit(X_train, y_train)
print(est.score(X_test, y_test))
# Out:
# 1.0

# %% [markdown]
# Let's consider now a larger dataset and see how **TabICL** behaves.

# %%
import pandas as pd
from pathlib import Path
from urllib.request import urlretrieve

DATA_DIR = Path().parent / "data"

url = ("https://archive.ics.uci.edu/ml/machine-learning-databases"
       "/adult/adult.data")

local_filename =  DATA_DIR/ Path(url).name
if not local_filename.exists():
    print("Downloading Adult Census datasets from UCI")
    DATA_DIR.mkdir(exist_ok=True)
    urlretrieve(url, local_filename)

names = ("age, workclass, fnlwgt, education, education-num, "
         "marital-status, occupation, relationship, race, sex, "
         "capital-gain, capital-loss, hours-per-week, "
         "native-country, income").split(', ')
df = pd.read_csv(local_filename, names=names)
df = df.rename(columns={'income': 'class'})

columns_to_plot = [
    "age",
    "education-num",
    "capital-loss",
    "capital-gain",
    "hours-per-week",
    "class",
]
df = df[columns_to_plot]
print(df.shape)
df.head()
# Out:
# Downloading Adult Census datasets from UCI
# (32561, 6)
#    age  education-num  capital-loss  capital-gain  hours-per-week   class
# 0   39             13             0          2174              40   <=50K
# 1   50             13             0             0              13   <=50K
# 2   38              9             0             0              40   <=50K
# 3   53              7             0             0              40   <=50K
# 4   28             13             0             0              40   <=50K

# %%
target_name = "class"
target = df[target_name]
X, y = df.iloc[:,:-1].values, target.values
y = (y == ' <=50K').astype(np.int8)

# %%
clf_icl = TabICLClassifier(n_estimators=4)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42)
clf_icl.fit(X_train, y_train)
print(clf_icl.score(X_test, y_test))
# Out:
# 0.8214219244369998

# %%
from sklearn.ensemble import HistGradientBoostingClassifier

clf_hgbr = HistGradientBoostingClassifier()
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42)
clf_hgbr.fit(X_train, y_train)
print(clf_hgbr.score(X_test, y_test))
# Out:
# 0.8397543271915131

# %%
# !pip install uv
# !uv pip install autogluon.tabular[mitra]
# Out:
# Collecting uv
#   Downloading uv-0.9.18-py3-none-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (11 kB)
# Downloading uv-0.9.18-py3-none-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (22.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 22.2/22.2 MB 68.1 MB/s eta 0:00:00
# Installing collected packages: uv
# Successfully installed uv-0.9.18
# Using Python 3.12.12 environment at: /usr
# Resolved 71 packages in 601ms
# Prepared 15 packages in 30.30s
# Uninstalled 5 packages in 1.20s
# Installed 15 packages in 545ms
#  + autogluon-common==1.4.0
#  + autogluon-core==1.4.0
#  + autogluon-features==1.4.0
#  + autogluon-tabular==1.4.0
#  + boto3==1.42.12
#  + botocore==1.42.12
#  + einx==0.3.0
#  + jmespath==1.0.1
#  + loguru==0.7.3
#  - nvidia-cudnn-cu12==9.10.2.21
#  + nvidia-cudnn-cu12==9.5.1.17
#  - nvidia-cusparselt-cu12==0.7.1
#  + nvidia-cusparselt-cu12==0.6.3
#  - nvidia-nccl-cu12==2.27.5
#  + nvidia-nccl-cu12==2.26.2
#  + s3transfer==0.16.0
#  - torch==2.9.0+cu126
#  + torch==2.7.1
#  - triton==3.5.0
#  + triton==3.3.1

# %%
import pandas as pd
from autogluon.tabular import TabularDataset, TabularPredictor
from sklearn.model_selection import train_test_split
from sklearn.datasets import fetch_california_housing

# Load datasets
california_data = fetch_california_housing(as_frame=True)
california_df = california_data.frame
california_df['MedHouseVal'] = california_data.target

print("Dataset shapes:")
print(f"California Housing: {california_df.shape}")

# Create train/test splits (80/20)
california_train, california_test = train_test_split(california_df, test_size=0.2, random_state=42)

print("Training set sizes:")
print(f"California Housing: {len(california_train)} samples")

# Convert to TabularDataset
california_train_data = TabularDataset(california_train)
california_test_data = TabularDataset(california_test)

# Create predictor with Mitra
print("Training Mitra regressor on California housing dataset...")
mitra_predictor = TabularPredictor(label='MedHouseVal', problem_type='regression')
mitra_predictor.fit(
    california_train_data,
    hyperparameters={
        'MITRA': {'fine_tune': False}
    },
   )

print("\nMitra training completed!")

# Make predictions
mitra_predictions = mitra_predictor.predict(california_test_data)
print("Sample Mitra predictions:")
print(mitra_predictions.head(10))

# Show model leaderboard
print("\nMitra Model Leaderboard:")
mitra_predictor.leaderboard(california_test_data)
# Out:
# No path specified. Models will be saved in: "AutogluonModels/ag-20251218_090244"
# Verbosity: 2 (Standard Logging)
# =================== System Info ===================
# AutoGluon Version:  1.4.0
# Python Version:     3.12.12
# Operating System:   Linux
# Platform Machine:   x86_64
# Platform Version:   #1 SMP Thu Oct  2 10:42:05 UTC 2025
# CPU Count:          2
# Memory Avail:       8.94 GB / 12.67 GB (70.5%)
# Disk Space Avail:   69.27 GB / 112.64 GB (61.5%)
# ===================================================
# No presets specified! To achieve strong results with AutoGluon, it is recommended to use the available presets. Defaulting to `'medium'`...
# 	Recommended Presets (For more details refer to https://auto.gluon.ai/stable/tutorials/tabular/tabular-essentials.html#presets):
# 	presets='extreme' : New in v1.4: Massively better than 'best' on datasets <30000 samples by using new models meta-learned on https://tabarena.ai: TabPFNv2, TabICL, Mitra, and TabM. Absolute best accuracy. Requires a GPU. Recommended 64 GB CPU memory and 32+ GB GPU memory.
# 	presets='best'    : Maximize accuracy. Recommended for most users. Use in competitions and benchmarks.
# 	presets='high'    : Strong accuracy with fast inference speed.
# 	presets='good'    : Good accuracy with very fast inference speed.
# 	presets='medium'  : Fast training time, ideal for initial prototyping.
# Dataset shapes:
# California Housing: (20640, 9)
# Training set sizes:
# California Housing: 16512 samples
# Training Mitra regressor on California housing dataset...
# Beginning AutoGluon training ...
# AutoGluon will save models to "/content/AutogluonModels/ag-20251218_090244"
# Train Data Rows:    16512
# Train Data Columns: 8
# Label Column:       MedHouseVal
# Problem Type:       regression
# Preprocessing data ...
# Using Feature Generators to preprocess the data ...
# Fitting AutoMLPipelineFeatureGenerator...
# 	Available Memory:                    9159.24 MB
# 	Train Data (Original)  Memory Usage: 1.01 MB (0.0% of available memory)
# 	Inferring data type of each feature based on column values. Set feature_metadata_in to manually specify special dtypes of the features.
# 	Stage 1 Generators:
# 		Fitting AsTypeFeatureGenerator...
# 	Stage 2 Generators:
# 		Fitting FillNaFeatureGenerator...
# 	Stage 3 Generators:
# 		Fitting IdentityFeatureGenerator...
# 	Stage 4 Generators:
# 		Fitting DropUniqueFeatureGenerator...
# 	Stage 5 Generators:
# 		Fitting DropDuplicatesFeatureGenerator...
# 	Types of features in original data (raw dtype, special dtypes):
# 		('float', []) : 8 | ['MedInc', 'HouseAge', 'AveRooms', 'AveBedrms', 'Population', ...]
# 	Types of features in processed data (raw dtype, special dtypes):
# 		('float', []) : 8 | ['MedInc', 'HouseAge', 'AveRooms', 'AveBedrms', 'Population', ...]
# 	0.1s = Fit runtime
# 	8 features in original data used to generate 8 features in processed data.
# 	Train Data (Processed) Memory Usage: 1.01 MB (0.0% of available memory)
# Data preprocessing and feature engineering runtime = 0.07s ...
# AutoGluon will gauge predictive performance using evaluation metric: 'root_mean_squared_error'
# 	This metric's sign has been flipped to adhere to being higher_is_better. The metric score can be multiplied by -1 to get the metric value.
# 	To change this, specify the eval_metric parameter of Predictor()
# Automatically generating train/validation split with holdout_frac=0.1, Train Rows: 14860, Val Rows: 1652
# User-specified model hyperparameters to be fit:
# {
# 	'MITRA': [{'fine_tune': False}],
# }
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: Mitra ...
# 	Warning: Not enough memory to safely train model. Estimated to require 14.035 GB out of 8.945 GB available memory (156.908%)... (90.000% of avail memory is the max safe size)
# 	To force training the model, specify the model hyperparameter "ag.max_memory_usage_ratio" to a larger value (currently 1.0, set to >=1.79 to avoid the error)
# 		To set the same value for all models, do the following when calling predictor.fit: `predictor.fit(..., ag_args_fit={"ag.max_memory_usage_ratio": VALUE})`
# 		Setting "ag.max_memory_usage_ratio" to values above 1 may result in out-of-memory errors. You may consider using a machine with more memory as a safer alternative.
# 	Not enough memory to train Mitra... Skipping this model.
# No base models to train on, skipping auxiliary stack level 2...
# Warning: AutoGluon did not successfully train any models
# AutoGluon training complete, total runtime = 0.4s ... Best model: None
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# /tmp/ipython-input-2849393627.py in <cell line: 0>()
#      25 print("Training Mitra regressor on California housing dataset...")
#      26 mitra_predictor = TabularPredictor(label='MedHouseVal', problem_type='regression')
# ---> 27 mitra_predictor.fit(
#      28     california_train_data,
#      29     hyperparameters={
#
# /usr/local/lib/python3.12/dist-packages/autogluon/core/utils/decorators.py in _call(*args, **kwargs)
#      29         def _call(*args, **kwargs):
#      30             gargs, gkwargs = g(*other_args, *args, **kwargs)
# ---> 31             return f(*gargs, **gkwargs)
#      32
#      33         return _call
#
# /usr/local/lib/python3.12/dist-packages/autogluon/tabular/predictor/predictor.py in fit(self, train_data, tuning_data, time_limit, presets, hyperparameters, feature_metadata, infer_limit, infer_limit_batch_size, fit_weighted_ensemble, fit_full_last_level_weighted_ensemble, full_weighted_ensemble_additionally, dynamic_stacking, calibrate_decision_threshold, num_cpus, num_gpus, fit_strategy, memory_limit, callbacks, **kwargs)
#    1361         self._fit_strategy = fit_strategy
#    1362
# -> 1363         self._fit(ag_fit_kwargs=ag_fit_kwargs, ag_post_fit_kwargs=ag_post_fit_kwargs)
#    1364
#    1365         return self
#
# /usr/local/lib/python3.12/dist-packages/autogluon/tabular/predictor/predictor.py in _fit(self, ag_fit_kwargs, ag_post_fit_kwargs)
#    1369         self._learner.fit(**ag_fit_kwargs)
#    1370         self._set_post_fit_vars()
# -> 1371         self._post_fit(**ag_post_fit_kwargs)
#    1372         self.save()
#    1373
#
# /usr/local/lib/python3.12/dist-packages/autogluon/tabular/predictor/predictor.py in _post_fit(self, keep_only_best, refit_full, set_best_to_refit_full, save_space, calibrate, calibrate_decision_threshold, infer_limit, num_cpus, num_gpus, refit_full_kwargs, fit_strategy, raise_on_no_models_fitted)
#    1701         if not self.model_names():
#    1702             if raise_on_no_models_fitted:
# -> 1703                 raise RuntimeError(
#    1704                     "No models were trained successfully during fit()."
#    1705                     " Inspect the log output or increase verbosity to determine why no models were fit."
#
# RuntimeError: No models were trained successfully during fit(). Inspect the log output or increase verbosity to determine why no models were fit. Alternatively, set `raise_on_no_models_fitted` to False during the fit call.
